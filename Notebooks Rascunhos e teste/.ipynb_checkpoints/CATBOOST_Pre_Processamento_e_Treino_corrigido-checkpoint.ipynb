# %% [markdown]
# # CATBOOST — Pré-processamento, Treino, CV (no treino), Optuna e Avaliação no Teste (holdout do treino)

# %%
import os, re, json, math, warnings
from pathlib import Path
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedGroupKFold
from sklearn.metrics import mean_squared_log_error, mean_absolute_percentage_error

from catboost import CatBoostRegressor, Pool
import optuna

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import os, json, joblib
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sqlalchemy.engine import URL
from pathlib import Path
import unicodedata as ud
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, StratifiedGroupKFold
import optuna
from sklearn.metrics import mean_squared_error,  mean_squared_log_error, mean_absolute_percentage_error
from lightgbm import LGBMRegressor
import lightgbm as lgb

# %%
load_dotenv()

HOST = os.getenv("PGHOST")
PORT = os.getenv("PGPORT")
DB   = os.getenv("PGDATABASE")
USR  = os.getenv("PGUSER")
PWD  = os.getenv("PGPASSWORD")

# %%
# 1) Caminho .env local
ENV_PATH = Path(r"C:\Users\cicer\Documents\Case Técnico Paipe\Análise Exploratória\.env")
print("Arquivo .env existe?", ENV_PATH.exists(), "\nCaminho:", ENV_PATH)

# 2) Carrega o .env
load_dotenv(dotenv_path=ENV_PATH, override=True)

# 3) Confere o que foi lido
cfg = {k: os.getenv(k) for k in ["PGHOST", "PGPORT", "PGDATABASE", "PGUSER"]}
print(cfg, "| PGPASSWORD set?", bool(os.getenv("PGPASSWORD")))
# Out:
# Arquivo .env existe? True
# Caminho: C:\Users\cicer\Documents\Case Técnico Paipe\Análise Exploratória\.env
# {'PGHOST': 'localhost', 'PGPORT': '5432', 'PGDATABASE': 'PaipeTech', 'PGUSER': 'postgres'} | PGPASSWORD set? True

# %%
HOST = os.getenv("PGHOST", "localhost")
PORT = int(os.getenv("PGPORT") or 5432)
DB   = os.getenv("PGDATABASE")
USR  = os.getenv("PGUSER")
PWD  = os.getenv("PGPASSWORD")

url = URL.create(
    "postgresql+psycopg2",
    username=USR,
    password=PWD,   
    host=HOST,
    port=PORT,
    database=DB,
)

engine = create_engine(url, pool_pre_ping=True)

# teste rápido
with engine.begin() as conn:
    print("DB atual:", conn.execute(text("SELECT current_database()")).scalar())
    print("Versão:",  conn.execute(text("SELECT version()")).scalar().splitlines()[0])
# Out:
# DB atual: PaipeTech
# Versão: PostgreSQL 18.0 on x86_64-windows, compiled by msvc-19.44.35215, 64-bit

# %%
df = pd.read_sql(text("SELECT * FROM public.df_train"), engine)

# %%
import os, re, json, math, warnings
from pathlib import Path
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedGroupKFold
from sklearn.metrics import mean_squared_log_error, mean_absolute_percentage_error

from catboost import CatBoostRegressor, Pool
import optuna

pd.set_option("display.max_columns", None)
warnings.filterwarnings("ignore")

SEED = 42
BASE = Path(".").resolve()

SAVE_DIR = BASE / "models_catboost_corrigido"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

print("Base:", BASE)
print("Save dir:", SAVE_DIR)
# Out:
# Base: C:\Users\cicer\Documents\Case Técnico Paipe\Tratamento e Treinamento
# Save dir: C:\Users\cicer\Documents\Case Técnico Paipe\Tratamento e Treinamento\models_catboost_corrigido

# %%
# Carregamento de dados
CSV_CANDIDATES = [
    BASE / "train_houses.csv",
    BASE / "df_train.csv",
    BASE / "dados_treino.csv",
]

# if 'df' in globals() and isinstance(df, pd.DataFrame):
#     train_raw = df.copy()
# else:
#     csv_path = next((p for p in CSV_CANDIDATES if p.exists()), None)
#     if csv_path is None:
#         raise FileNotFoundError("Não encontrei um CSV de treino. Defina um DataFrame 'df' ou coloque 'train_houses.csv' na pasta.")
#     train_raw = pd.read_csv(csv_path)

df.columns = [c.lower() for c in df.columns]
train_raw = df.copy()
print(train_raw.shape, "linhas x colunas")
train_raw.head(3)
# Out:
# (325260, 38) linhas x colunas
#    id                                 type            region  \
# 0  16         Pre-owned Condominiums, etc.              None
# 1  17  Residential Land(Land and Building)  Residential Area
# 2  18          Residential Land(Land Only)  Residential Area
#
#    municipalitycode prefecture   municipality      districtname  \
# 0             13103      Tokyo    Minato Ward            Kaigan
# 1             13120      Tokyo    Nerima Ward           Nishiki
# 2             13201      Tokyo  Hachioji City  Shimoongatamachi
#
#   neareststation timetoneareststation  mintimetoneareststation  \
# 0      Takeshiba                    1                      1.0
# 1   Kamiitabashi                   15                     15.0
# 2  Takao (Tokyo)              1H-1H30                     60.0
#
#    maxtimetoneareststation floorplan  area  areaisgreaterflag  unitprice  \
# 0                      1.0        1K    35                  0        NaN
# 1                     15.0      None   110                  0        NaN
# 2                     90.0      None   135                  0   100000.0
#
#    pricepertsubo                landshape  frontage  frontageisgreaterflag  \
# 0            NaN                     None       NaN                  False
# 1            NaN  Semi-rectangular Shaped      12.0                  False
# 2       340000.0         Irregular Shaped      10.0                  False
#
#    totalfloorarea  totalfloorareaisgreaterflag  buildingyear  prewarbuilding  \
# 0             NaN                            0        1979.0               0
# 1           105.0                            0        2013.0               0
# 2             NaN                            0           NaN               0
#
#   structure    use purpose direction classification  breadth  \
# 0       SRC  House    None      None           None      NaN
# 1         W  House    None      East   Private Road      4.0
# 2      None   None    None      East   Private Road      4.5
#
#                                         cityplanning  coverageratio  \
# 0                              Quasi-industrial Zone           60.0
# 1  Category I Exclusively Low-story Residential Zone           60.0
# 2  Category I Exclusively Low-story Residential Zone           40.0
#
#    floorarearatio            period  year  quarter renovation  \
# 0           400.0  1st quarter 2011  2011        1       Done
# 1           200.0  3rd quarter 2013  2013        3       None
# 2            80.0  4th quarter 2007  2007        4       None
#
#                            remarks  tradeprice
# 0                             None  24000000.0
# 1  Dealings including private road  51000000.0
# 2                             None  14000000.0

# %%
# Definições de features
X_COLS = [
    "type","region","municipalitycode","municipality","districtname",
    "mintimetoneareststation","maxtimetoneareststation","floorplan","landshape",
    "buildingyear","structure","use","purpose","direction","classification",
    "cityplanning","coverageratio","floorarearatio","year","quarter","renovation",
    "time_to_station_mean","log_totalfloorarea","log_area","log_frontage","log_breadth"
]
CAT_COLS = [
    "type","region","municipalitycode","municipality","districtname",
    "floorplan","landshape","structure","use","purpose",
    "direction","classification","cityplanning","renovation"
]

# %%
# Funções de features (CatBoost-friendly)
def build_features_cb(df: pd.DataFrame, X_COLS: list[str], cat_cols: list[str]) -> pd.DataFrame:
    df = df.copy()
    def _to_num(s): return pd.to_numeric(s, errors="coerce")
    base_t = _to_num(df.get("timetoneareststation", np.nan))
    min_t  = _to_num(df.get("mintimetoneareststation", np.nan))
    max_t  = _to_num(df.get("maxtimetoneareststation", np.nan))
    time_mean = base_t.copy() if isinstance(base_t, pd.Series) else pd.Series(np.nan, index=df.index)
    mnan = time_mean.isna()
    time_mean[mnan] = (min_t[mnan] + max_t[mnan]) / 2.0
    df["time_to_station_mean"] = time_mean

    for src, dst in [
        ("totalfloorarea", "log_totalfloorarea"),
        ("area",           "log_area"),
        ("frontage",       "log_frontage"),
        ("breadth",        "log_breadth"),
    ]:
        if src in df.columns:
            df[dst] = np.log1p(pd.to_numeric(df[src], errors="coerce").fillna(0))

    for c in ["buildingyear","coverageratio","floorarearatio","year","quarter"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")

    if "renovation" in df.columns:
        df["renovation"] = (
            df["renovation"].astype("string").str.strip()
              .replace({"Yes":"Done","No":"Not yet","nan":"Not yet","NaN":"Not yet"})
        )

    for c in X_COLS:
        if c not in df.columns:
            df[c] = "Missing" if c in cat_cols else np.nan

    for c in cat_cols:
        df[c] = df[c].astype("string").fillna("Missing").astype(str)
    for c in [col for col in X_COLS if col not in cat_cols]:
        df[c] = pd.to_numeric(df[c], errors="coerce").astype(float)

    return df

def prepare_for_catboost(X: pd.DataFrame, cat_cols: list[str]) -> pd.DataFrame:
    X = X.copy()
    for c in cat_cols:
        X[c] = X[c].astype("string").fillna("Missing").astype(str)
    num_cols = [c for c in X.columns if c not in cat_cols]
    for c in num_cols:
        X[c] = pd.to_numeric(X[c], errors="coerce").astype(float)
    return X

# %%
# Construção de features
train_f = build_features_cb(train_raw, X_COLS, CAT_COLS)
print(train_f.shape)
train_f.head(3)
# Out:
# (325260, 43)
#    id                                 type            region municipalitycode  \
# 0  16         Pre-owned Condominiums, etc.           Missing            13103
# 1  17  Residential Land(Land and Building)  Residential Area            13120
# 2  18          Residential Land(Land Only)  Residential Area            13201
#
#   prefecture   municipality      districtname neareststation  \
# 0      Tokyo    Minato Ward            Kaigan      Takeshiba
# 1      Tokyo    Nerima Ward           Nishiki   Kamiitabashi
# 2      Tokyo  Hachioji City  Shimoongatamachi  Takao (Tokyo)
#
#   timetoneareststation  mintimetoneareststation  maxtimetoneareststation  \
# 0                    1                      1.0                      1.0
# 1                   15                     15.0                     15.0
# 2              1H-1H30                     60.0                     90.0
#
#   floorplan  area  areaisgreaterflag  unitprice  pricepertsubo  \
# 0        1K    35                  0        NaN            NaN
# 1   Missing   110                  0        NaN            NaN
# 2   Missing   135                  0   100000.0       340000.0
#
#                  landshape  frontage  frontageisgreaterflag  totalfloorarea  \
# 0                  Missing       NaN                  False             NaN
# 1  Semi-rectangular Shaped      12.0                  False           105.0
# 2         Irregular Shaped      10.0                  False             NaN
#
#    totalfloorareaisgreaterflag  buildingyear  prewarbuilding structure  \
# 0                            0        1979.0               0       SRC
# 1                            0        2013.0               0         W
# 2                            0           NaN               0   Missing
#
#        use  purpose direction classification  breadth  \
# 0    House  Missing   Missing        Missing      NaN
# 1    House  Missing      East   Private Road      4.0
# 2  Missing  Missing      East   Private Road      4.5
#
#                                         cityplanning  coverageratio  \
# 0                              Quasi-industrial Zone           60.0
# 1  Category I Exclusively Low-story Residential Zone           60.0
# 2  Category I Exclusively Low-story Residential Zone           40.0
#
#    floorarearatio            period    year  quarter renovation  \
# 0           400.0  1st quarter 2011  2011.0      1.0       Done
# 1           200.0  3rd quarter 2013  2013.0      3.0    Missing
# 2            80.0  4th quarter 2007  2007.0      4.0    Missing
#
#                            remarks  tradeprice  time_to_station_mean  \
# 0                             None  24000000.0                   1.0
# 1  Dealings including private road  51000000.0                  15.0
# 2                             None  14000000.0                  75.0
#
#    log_totalfloorarea  log_area  log_frontage  log_breadth
# 0            0.000000  3.583519      0.000000     0.000000
# 1            4.663439  4.709530      2.564949     1.609438
# 2            0.000000  4.912655      2.397895     1.704748

# %%
# Alvo seguro + split
tp_raw = train_f["tradeprice"] if "tradeprice" in train_f.columns else None
if tp_raw is None:
    raise KeyError("Coluna 'tradeprice' não encontrada no dataset.")

y_raw = pd.to_numeric(tp_raw, errors="coerce")
if y_raw.isna().mean() > 0.5:
    y_raw = pd.to_numeric(tp_raw.astype(str).str.replace(r"[^\d\.\-]", "", regex=True), errors="coerce")

mask = y_raw.notna() & (y_raw > 0)

print("Total linhas:", len(y_raw))
print("Com preço válido (>0):", int(mask.sum()))
print("Descartadas:", int((~mask).sum()))

X_all = train_f.loc[mask, X_COLS].copy()
y_raw = y_raw.loc[mask]
y_log = np.log1p(y_raw)
assert np.isfinite(y_log).all(), "Ainda há NaN/inf em y_log após filtragem."

if "year" in train_f.columns:
    strata = pd.to_numeric(train_f.loc[mask, "year"], errors="coerce").fillna(-1).astype(int)
else:
    strata = None

stratify_arg = strata if strata is not None and strata.nunique() > 1 else None
X_tr, X_te, y_tr, y_te = train_test_split(X_all, y_log, test_size=0.2, random_state=42, stratify=stratify_arg)
print("Shapes -> X_tr:", X_tr.shape, "| X_te:", X_te.shape)
# Out:
# Total linhas: 325260
# Com preço válido (>0): 325260
# Descartadas: 0
# Shapes -> X_tr: (260208, 26) | X_te: (65052, 26)

# %%
# ==== CV no TREINO (sem Optuna) ====
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import mean_squared_log_error, mean_absolute_percentage_error
from catboost import CatBoostRegressor, Pool
import numpy as np, math, json

# Estratos e grupos (alinhados ao X_tr)
if "year" in train_f.columns:
    cv_strata = pd.to_numeric(train_f.loc[X_tr.index, "year"], errors="coerce").fillna(-1).astype(int)
else:
    cv_strata = pd.Series(-1, index=X_tr.index)

cv_groups = (
    train_f.loc[X_tr.index, "districtname"].astype(str).fillna("Missing")
    if "districtname" in train_f.columns else pd.Series("All", index=X_tr.index)
)

# Hiperparâmetros base (rápidos e fortes para CatBoost)
best_params = {
    "depth": 8,
    "learning_rate": 0.05,
    "l2_leaf_reg": 4.0,
    "subsample": 0.8,
    "colsample_bylevel": 0.8,
    "iterations": 3000,         # será ajustado pela mediana do ES
    "random_seed": SEED,
    "loss_function": "RMSE",
    "od_type": "Iter",
    "od_wait": 200,
    "verbose": False,
}

cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
rmsle_scores, mape_scores, best_iters = [], [], []

for tr_idx, va_idx in cv.split(X_tr, cv_strata, cv_groups):
    Xtr, Xva = X_tr.iloc[tr_idx], X_tr.iloc[va_idx]
    ytr, yva = y_tr.iloc[tr_idx], y_tr.iloc[va_idx]

    # preparar dados para CatBoost (strings nas categóricas, floats nas numéricas)
    Xtr_cb = prepare_for_catboost(Xtr, CAT_COLS)
    Xva_cb = prepare_for_catboost(Xva, CAT_COLS)
    cat_idx = [Xtr_cb.columns.get_loc(c) for c in CAT_COLS if c in Xtr_cb.columns]

    train_pool = Pool(Xtr_cb, ytr, cat_features=cat_idx)
    valid_pool = Pool(Xva_cb, yva, cat_features=cat_idx)

    cb = CatBoostRegressor(**best_params)
    cb.fit(train_pool, eval_set=valid_pool)  # early stopping via od_type/od_wait

    pred = np.maximum(np.expm1(cb.predict(Xva_cb)), 0)
    true = np.expm1(yva)

    rmsle_scores.append(math.sqrt(mean_squared_log_error(true, pred)))
    mape_scores.append(mean_absolute_percentage_error(true, pred))

    # capturar melhor iteração do ES (se disponível)
    try:
        bi = cb.get_best_iteration()
        best_iters.append(bi if (bi is not None and bi > 0) else best_params["iterations"])
    except Exception:
        best_iters.append(best_params["iterations"])

print(f"RMSLE (CV mean ± std): {np.mean(rmsle_scores):.4f} ± {np.std(rmsle_scores):.4f}")
print(f"MAPE  (CV mean ± std): {100*np.mean(mape_scores):.2f}% ± {100*np.std(mape_scores):.2f}%")

# Ajuste rápido: usar mediana de iterações observadas
best_params["iterations"] = int(np.median(best_iters))
print("Iterations ajustado (mediana do ES):", best_params["iterations"])

# Salvar para o bloco de treino final
with open(SAVE_DIR / "catboost_best_params.json", "w", encoding="utf-8") as f:
    json.dump(best_params, f, ensure_ascii=False, indent=2)
print("Hiperparâmetros salvos em:", SAVE_DIR / "catboost_best_params.json")

# %%
with open(SAVE_DIR / "catboost_best_params.json", "w", encoding="utf-8") as f:
    json.dump(study.best_params, f, ensure_ascii=False, indent=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 with open(SAVE_DIR / "catboost_best_params.json", "w", encoding="utf-8") as f:
# ----> 2     json.dump(study.best_params, f, ensure_ascii=False, indent=2)
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:120, in Study.best_params(self)
#     108 @property
#     109 def best_params(self) -> dict[str, Any]:
#     110     """Return parameters of the best trial in the study.
#     111
#     112     .. note::
#    (...)
#     117
#     118     """
# --> 120     return self.best_trial.params
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:156, in Study.best_trial(self)
#     139 @property
#     140 def best_trial(self) -> FrozenTrial:
#     141     """Return the best trial in the study.
#     142
#     143     .. note::
#    (...)
#     154
#     155     """
# --> 156     return self._get_best_trial(deepcopy=True)
#
# File ~\anaconda3\Lib\site-packages\optuna\study\study.py:308, in Study._get_best_trial(self, deepcopy)
#     302 if self._is_multi_objective():
#     303     raise RuntimeError(
#     304         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     305         "using Study.best_trials to retrieve a list containing the best trials."
#     306     )
# --> 308 best_trial = self._storage.get_best_trial(self._study_id)
#     310 # If the trial with the best value is infeasible, select the best trial from all feasible
#     311 # trials. Note that the behavior is undefined when constrained optimization without the
#     312 # violation value in the best-valued trial.
#     313 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File ~\anaconda3\Lib\site-packages\optuna\storages\_in_memory.py:252, in InMemoryStorage.get_best_trial(self, study_id)
#     249 best_trial_id = self._studies[study_id].best_trial_id
#     251 if best_trial_id is None:
# --> 252     raise ValueError("No trials are completed yet.")
#     253 elif len(self._studies[study_id].directions) > 1:
#     254     raise RuntimeError(
#     255         "Best trial can be obtained only for single-objective optimization."
#     256     )
#
# ValueError: No trials are completed yet.

# %%
# Treino final no TREINO + avaliação no TESTE
best_params = dict(study.best_params)
best_params.update({"random_seed": 42, "loss_function": "RMSE", "verbose": False})

X_tr_cb = prepare_for_catboost(X_tr, CAT_COLS)
X_te_cb = prepare_for_catboost(X_te, CAT_COLS)
cat_idx_final = [X_tr_cb.columns.get_loc(c) for c in CAT_COLS if c in X_tr_cb.columns]

train_pool = Pool(X_tr_cb, y_tr, cat_features=cat_idx_final)
test_pool  = Pool(X_te_cb, y_te, cat_features=cat_idx_final)

final_cb = CatBoostRegressor(**best_params)
final_cb.fit(train_pool)

model_path = (Path("models_catboost_corrigido") / "catboost_model_final.cbm")
final_cb.save_model(str(model_path))

meta = {"X_cols": X_COLS, "cat_cols": CAT_COLS}
with open(Path("models_catboost_corrigido") / "inference_meta.json", "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

y_pred_log = final_cb.predict(X_te_cb)
y_pred = np.maximum(np.expm1(y_pred_log), 0)
y_true = np.expm1(y_te)

rmsle = math.sqrt(mean_squared_log_error(y_true, y_pred))
mape  = mean_absolute_percentage_error(y_true, y_pred) * 100.0

print(f"RMSLE (teste holdout): {rmsle:.4f}")
print(f"MAPE  (teste holdout): {mape:.2f}%")

pred_df = pd.DataFrame({"y_true": y_true.values, "y_pred": y_pred})
pred_df.to_csv(Path("models_catboost_corrigido") / "holdout_predictions.csv", index=False)
print("Previsões do holdout salvas.")

# Importâncias
try:
    importances = final_cb.get_feature_importance(train_pool, type="PredictionValuesChange")
    fi = pd.DataFrame({"feature": X_tr_cb.columns, "importance": importances}).sort_values("importance", ascending=False)
    fi.to_csv(Path("models_catboost_corrigido") / "feature_importances.csv", index=False)
    print("Importâncias salvas.")
except Exception as e:
    print("Aviso (importâncias):", e)
